# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

model_name = "beomi/KcBERT-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

sentiment_analyzer = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)


# 2. 감성 분석 파이프라인 정의
sentiment_analyzer = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# 3. 분석할 문장과 키워드 정의
sentence = "이 제품은 디자인은 좋지만, 성능은 별로고 가격이 비싸다."
keywords = ["디자인", "성능", "가격"]

# 4. 키워드별 감성 분석 수행
results = {}
for keyword in keywords:
    # 각 키워드 중심으로 문장을 재구성
    keyword_sentence = f"{keyword}에 대해서 말하자면, {sentence}"
    # 감성 분석 수행
    analysis = sentiment_analyzer(keyword_sentence)[0]
    # 결과 저장
    results[keyword] = {
        "label": analysis["label"],
        "score": analysis["score"]
    }

# 5. 결과 출력
for keyword, analysis in results.items():
    print(f"키워드: {keyword}, 감성: {analysis['label']}, 확신도: {analysis['score']:.2f}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/250k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at beomi/KcBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 키워드: 디자인, 감성: LABEL_0, 확신도: 0.55
# 키워드: 성능, 감성: LABEL_0, 확신도: 0.54
# 키워드: 가격, 감성: LABEL_0, 확신도: 0.54

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

# 1. 모델과 토크나이저 로드 (한국어 감성 분석을 지원하는 모델 선택)
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# 2. 감성 분석 파이프라인 정의
sentiment_analyzer = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# 3. 분석할 문장과 키워드 정의
sentence = "이 제품은 디자인은 좋지만, 성능은 별로고 가격이 비싸다."
keywords = ["디자인", "성능", "가격"]

# 4. 키워드별 감성 분석 수행
results = {}
for keyword in keywords:
    # 각 키워드 중심으로 문장을 재구성
    keyword_sentence = f"{keyword}에 대해서 말하자면, {sentence}"
    # 감성 분석 수행
    analysis = sentiment_analyzer(keyword_sentence)[0]
    # 결과 저장
    results[keyword] = {
        "label": analysis["label"],
        "score": analysis["score"]
    }

# 5. 결과 출력
for keyword, analysis in results.items():
    print(f"키워드: {keyword}, 감성: {analysis['label']}, 확신도: {analysis['score']:.2f}")
# Out:
# 키워드: 디자인, 감성: 3 stars, 확신도: 0.57
# 키워드: 성능, 감성: 3 stars, 확신도: 0.59
# 키워드: 가격, 감성: 3 stars, 확신도: 0.59

# %%
from transformers import BertTokenizer, BertForSequenceClassification, pipeline

model_name = "monologg/kobert"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)

sentiment_analyzer = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

sentence = "이 제품은 디자인은 좋지만, 성능은 별로고 가격이 비싸다."
keywords = ["디자인", "성능", "가격"]

# 4. 키워드별 감성 분석 수행
results = {}
for keyword in keywords:
    # 각 키워드 중심으로 문장을 재구성
    keyword_sentence = f"{keyword}에 대해서 말하자면, {sentence}"
    # 감성 분석 수행
    analysis = sentiment_analyzer(keyword_sentence)[0]
    # 결과 저장
    results[keyword] = {
        "label": analysis["label"],
        "score": analysis["score"]
    }

# 5. 결과 출력
for keyword, analysis in results.items():
    print(f"키워드: {keyword}, 감성: {analysis['label']}, 확신도: {analysis['score']:.2f}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/263 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/77.8k [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'KoBertTokenizer'.
# The class this function is called from is 'BertTokenizer'.
# config.json:   0%|          | 0.00/426 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/369M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at monologg/kobert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 키워드: 디자인, 감성: LABEL_0, 확신도: 0.55
# 키워드: 성능, 감성: LABEL_0, 확신도: 0.55
# 키워드: 가격, 감성: LABEL_0, 확신도: 0.55

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

model_name = "monologg/koelectra-base-v3-discriminator"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

sentiment_analyzer = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

sentence = "이 제품은 디자인은 좋지만, 성능은 별로고 가격이 비싸다."
keywords = ["디자인", "성능", "가격"]

# 4. 키워드별 감성 분석 수행
results = {}
for keyword in keywords:
    # 각 키워드 중심으로 문장을 재구성
    keyword_sentence = f"{keyword}에 대해서 말하자면, {sentence}"
    # 감성 분석 수행
    analysis = sentiment_analyzer(keyword_sentence)[0]
    # 결과 저장
    results[keyword] = {
        "label": analysis["label"],
        "score": analysis["score"]
    }

# 5. 결과 출력
for keyword, analysis in results.items():
    print(f"키워드: {keyword}, 감성: {analysis['label']}, 확신도: {analysis['score']:.2f}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/263k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/452M [00:00<?, ?B/s]
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 키워드: 디자인, 감성: LABEL_1, 확신도: 0.50
# 키워드: 성능, 감성: LABEL_1, 확신도: 0.50
# 키워드: 가격, 감성: LABEL_1, 확신도: 0.51

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

model_name = "klue/bert-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

sentiment_analyzer = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

sentence = "이 제품은 디자인은 좋지만, 성능은 별로고 가격이 비싸다."
keywords = ["디자인", "성능", "가격"]

# 4. 키워드별 감성 분석 수행
results = {}
for keyword in keywords:
    # 각 키워드 중심으로 문장을 재구성
    keyword_sentence = f"{keyword}에 대해서 말하자면, {sentence}"
    # 감성 분석 수행
    analysis = sentiment_analyzer(keyword_sentence)[0]
    # 결과 저장
    results[keyword] = {
        "label": analysis["label"],
        "score": analysis["score"]
    }

# 5. 결과 출력
for keyword, analysis in results.items():
    print(f"키워드: {keyword}, 감성: {analysis['label']}, 확신도: {analysis['score']:.2f}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/425 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at klue/bert-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 키워드: 디자인, 감성: LABEL_1, 확신도: 0.50
# 키워드: 성능, 감성: LABEL_0, 확신도: 0.50
# 키워드: 가격, 감성: LABEL_1, 확신도: 0.51

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

model_name = "kykim/bert-kor-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

sentiment_analyzer = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

sentence = "이 제품은 디자인은 좋지만, 성능은 별로고 가격이 비싸다."
keywords = ["디자인", "성능", "가격"]

# 4. 키워드별 감성 분석 수행
results = {}
for keyword in keywords:
    # 각 키워드 중심으로 문장을 재구성
    keyword_sentence = f"{keyword}에 대해서 말하자면, {sentence}"
    # 감성 분석 수행
    analysis = sentiment_analyzer(keyword_sentence)[0]
    # 결과 저장
    results[keyword] = {
        "label": analysis["label"],
        "score": analysis["score"]
    }

# 5. 결과 출력
for keyword, analysis in results.items():
    print(f"키워드: {keyword}, 감성: {analysis['label']}, 확신도: {analysis['score']:.2f}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/80.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/344k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/476M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at kykim/bert-kor-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 키워드: 디자인, 감성: LABEL_1, 확신도: 0.54
# 키워드: 성능, 감성: LABEL_1, 확신도: 0.54
# 키워드: 가격, 감성: LABEL_1, 확신도: 0.55
